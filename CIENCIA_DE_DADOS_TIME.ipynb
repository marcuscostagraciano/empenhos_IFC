# %%
import pandas as pd

df = pd.read_csv("tempos_carregamento.csv")

# %%
df.plot(
    kind="line",
    grid=True,
    title="Tempo gasto na renderização de cada função",
    ylabel="Tempo (ms)",
    xlabel="Medição",
)
# Out:
# <Axes: title={'center': 'Tempo gasto na renderização de cada função'}, xlabel='Medição', ylabel='Tempo (ms)'>

# %%
df.plot(
    kind="box"
)
# Out:
# <Axes: >
